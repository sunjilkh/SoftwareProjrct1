# %% [markdown]
# Code Credit - https://twitter.com/pwang_szn/status/1642104548109201410/photo/1

# %%
# !pip install tiktoken
# !pip install python-multipart
# !pip install kaleido
# !pip install cohere umap-learn altair annoy datasets tqdm

# %%
# !pip install -q langchain openai chromadb

# %%
from langchain.document_loaders import CSVLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
import os

# %% [markdown]
# Get your OpenAI Key from here - https://platform.openai.com/account/api-keys

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!wget https://github.com/sunjilkh/SoftwareProjrct1/blob/main/DIU%20ChatBot%20Project/Copy%20of%20ChatBot.csv
# Out:
# --2023-11-21 09:09:00--  https://github.com/sunjilkh/SoftwareProjrct1/blob/main/DIU%20ChatBot%20Project/Copy%20of%20ChatBot.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 97519 (95K) [text/plain]
# Saving to: ‘Copy of ChatBot.csv’
#
# Copy of ChatBot.csv 100%[===================>]  95.23K  --.-KB/s    in 0.04s
#
# 2023-11-21 09:09:00 (2.33 MB/s) - ‘Copy of ChatBot.csv’ saved [97519/97519]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebook /ChatBot.csv')
#file1 = open('/content/Copy of ChatBot.csv', "r")
df.head()

# %%
# Load the documents
loader = CSVLoader(file_path='/content/drive/MyDrive/Colab Notebook /ChatBot.csv')

# %%
# Create an index using the loaded documents
index_creator = VectorstoreIndexCreator()
docsearch = index_creator.from_loaders([loader])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-16-d4743758fabe> in <cell line: 3>()
#       1 # Create an index using the loaded documents
#       2 index_creator = VectorstoreIndexCreator()
# ----> 3 docsearch = index_creator.from_loaders([loader])
#
# /usr/local/lib/python3.10/dist-packages/langchain/indexes/vectorstore.py in from_loaders(self, loaders)
#      80         for loader in loaders:
#      81             docs.extend(loader.load())
# ---> 82         return self.from_documents(docs)
#      83
#      84     def from_documents(self, documents: List[Document]) -> VectorStoreIndexWrapper:
#
# /usr/local/lib/python3.10/dist-packages/langchain/indexes/vectorstore.py in from_documents(self, documents)
#      85         """Create a vectorstore index from documents."""
#      86         sub_docs = self.text_splitter.split_documents(documents)
# ...

# %%
# Create a question-answering chain using the index
chain = RetrievalQA.from_chain_type(llm=OpenAI(), chain_type="stuff", retriever=docsearch.vectorstore.as_retriever(), input_key="question")

# %%
# Pass a query to the chain
query = input('Enter your question :\n')
#query = "What is the cost for DIU hall?"
response = chain({"question": query})

# %%
print(response['result'])
# Out:
#  No, we do not have a column called age.
